# %%
import requests
import json

# %%
def query_ollama_api(model: str, prompt: str) -> str:
    url = "http://localhost:11434/api/generate"
    payload = {"model": model, "prompt": prompt}
    
    response = requests.post(url, json=payload)
    response.raise_for_status()

    output = ""
    for line in response.iter_lines():
        if line:
            data = line.decode("utf-8")
            obj = json.loads(data)
            if "response" in obj:
                output += obj["response"]
    return output

# %%
model = "llama3"
prompt = "Explain quantum computing in simple terms."
print(query_ollama_api(model, prompt))
# Out:
# Quantum computing! It's a fascinating topic that can be tricky to grasp, but I'll try to break it down in simple terms.
#
# **What is quantum computing?**
#
# Classical computers use "bits" (0s and 1s) to process information. Quantum computers use "qubits" (quantum bits), which are fundamentally different. Qubits can exist in multiple states at the same time, allowing them to process vast amounts of data simultaneously.
#
# **How does it work?**
#
# Imagine you have a coin that can be either heads or tails. A classical computer would consider each possibility separately: "heads" or "tails." But with a qubit, it's like having a special coin that can exist in both states at the same time – both heads and tails simultaneously!
#
# This property is called superposition. Qubits can also become "entangled," meaning their properties are connected even when separated by large distances. When you measure or interact with one qubit, it instantly affects the other, no matter how far apart they are.
#
# **Why is quantum computing powerful?**
#
# 1. **Speed**: Quantum computers can process vast amounts of data in parallel, making them incredibly fast for certain types of calculations.
# 2. **Complexity**: Qubits allow for simulations and computations that would be impossible or impractical on classical computers.
# 3. **Cryptographic security**: Quantum computers are resistant to some forms of hacking, as they're immune to certain encryption methods used by classical computers.
#
# **Example: Simulating a molecule**
#
# Imagine you want to simulate the behavior of a complex molecule, like a protein. A classical computer would need to consider each atom's position and interaction separately, which is computationally expensive.
#
# A quantum computer, on the other hand, can simulate the entire molecule simultaneously, taking into account all possible interactions and positions. This allows for much faster and more accurate simulations!
#
# **In summary**
#
# Quantum computing is a new way of processing information using qubits that exist in multiple states at once. This enables quantum computers to perform calculations that are faster, more complex, and more secure than classical computers. The possibilities are vast, from medicine and finance to materials science and artificial intelligence – the future looks exciting!
