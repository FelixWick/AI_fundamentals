# %%
! pip install transformers
# Out:
# Requirement already satisfied: transformers in /Users/wick/language_models/.venv/lib/python3.13/site-packages (4.57.1)
# Requirement already satisfied: filelock in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from transformers) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from transformers) (2025.10.23)
# Requirement already satisfied: requests in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from requests->transformers) (2025.10.5)

# %%
from transformers import AutoTokenizer, AutoModel
from numpy import dot
from numpy.linalg import norm

# %%
# Load small Transformer model (distilbert for speed)
model_name = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# %%
# Example sentence and target word
sentence = "The king and queen ruled wisely."
target_word = "queen"

# %%
# Tokenize sentence
inputs = tokenizer(sentence, return_tensors="pt")
outputs = model(**inputs)

# %%
# Get hidden states (last layer)
last_hidden = outputs.last_hidden_state[0]  # shape: [seq_len, hidden_size]

# %%
# Map tokens back to words
tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"][0])

# %%
# Find embedding for the target word
# For simplicity, take the first token that matches (can split subwords)
for idx, tok in enumerate(tokens):
    if target_word in tok:
        word_embedding = last_hidden[idx].detach().numpy()
        break

print(f"Word embedding length: {len(word_embedding)}")
print(f"First 10 values: {word_embedding[:10]}")
# Out:
# Word embedding length: 768
# First 10 values: [ 0.604848   -0.329022   -0.11489624 -0.08473329 -0.02040417 -0.6469731
#  -0.02629811  0.10178638 -0.18362316 -0.16340357]

# %%
# Example: compute similarity with another word in context
target_word2 = "king"
for idx, tok in enumerate(tokens):
    if target_word2 in tok:
        word_embedding2 = last_hidden[idx].detach().numpy()
        break

similarity = dot(word_embedding, word_embedding2) / (norm(word_embedding) * norm(word_embedding2))
print(f"Cosine similarity between '{target_word}' and '{target_word2}': {similarity:.3f}")
# Out:
# Cosine similarity between 'queen' and 'king': 0.829
