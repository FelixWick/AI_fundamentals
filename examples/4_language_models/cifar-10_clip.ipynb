# %% [markdown]
# see https://github.com/openai/CLIP

# %%
! pip install git+https://github.com/openai/CLIP.git
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /private/var/folders/9g/fz6w6gks1dq2j6bw3pg865kr0000gn/T/pip-req-build-r108z586
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /private/var/folders/9g/fz6w6gks1dq2j6bw3pg865kr0000gn/T/pip-req-build-r108z586
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ftfy (from clip==1.0)
#   Using cached ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: packaging in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from clip==1.0) (25.0)
# Requirement already satisfied: regex in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from clip==1.0) (2025.9.1)
# Requirement already satisfied: tqdm in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from clip==1.0) (4.67.1)
# Requirement already satisfied: torch in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from clip==1.0) (2.8.0)
# Requirement already satisfied: torchvision in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from clip==1.0) (0.23.0)
# Requirement already satisfied: wcwidth in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from torch->clip==1.0) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from torch->clip==1.0) (4.15.0)
# Requirement already satisfied: setuptools in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from torch->clip==1.0) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from torch->clip==1.0) (1.14.0)
# Requirement already satisfied: networkx in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from torch->clip==1.0) (3.5)
# Requirement already satisfied: jinja2 in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from torch->clip==1.0) (3.1.6)
# Requirement already satisfied: fsspec in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from torch->clip==1.0) (2025.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from sympy>=1.13.3->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from jinja2->torch->clip==1.0) (3.0.2)
# Requirement already satisfied: numpy in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from torchvision->clip==1.0) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from torchvision->clip==1.0) (11.3.0)
# Using cached ftfy-6.3.1-py3-none-any.whl (44 kB)
# Building wheels for collected packages: clip
#   Building wheel for clip (pyproject.toml) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369549 sha256=f84593c69defbffc1c8528345fb3e100692c4b2b63cf03dc694430e1ebadcb3d
#   Stored in directory: /private/var/folders/9g/fz6w6gks1dq2j6bw3pg865kr0000gn/T/pip-ephem-wheel-cache-0y3u1mja/wheels/cb/a8/74/5f32d6cf0407457f0f62737b6da5c14eb86b9cac476fdf630d
# Successfully built clip
# Installing collected packages: ftfy, clip
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [clip]
# Successfully installed clip-1.0 ftfy-6.3.1

# %%
import torch
import clip
from torchvision import datasets, transforms
from tqdm import tqdm  # for progress bar

# %%
if torch.cuda.is_available():
    dev = "cuda:0"
elif torch.backends.mps.is_available():
    dev = "mps"
else:
    dev = "cpu"
device = torch.device(dev)
device
# Out:
# device(type='mps')

# %% [markdown]
# load the CLIP model

# %%
model, preprocess = clip.load("ViT-B/32", device=device)

# %% [markdown]
# The class labels are converted into text prompts like "a photo of a cat", which are then tokenized.

# %%
# CIFAR-10 class labels
cifar10_classes = [
    "airplane", "automobile", "bird", "cat", "deer",
    "dog", "frog", "horse", "ship", "truck"
]

text_inputs = clip.tokenize([f"a photo of a {c}" for c in cifar10_classes]).to(device)
# text_inputs = clip.tokenize([f"a blurry image of a {c}" for c in cifar10_classes]).to(device)

# %% [markdown]
# load CIFAR-10 test dataset (no training, as we go for zero-shot)

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize to CLIP input size
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

testset = datasets.CIFAR10(root="./data", train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=1, shuffle=True)

# %% [markdown]
# pick just use one sample to show zero-shot classification

# %%
image, label = next(iter(testloader))
image = image.to(device)

# %% [markdown]
# CLIP encodes both the image and text into a shared embedding space.

# %%
with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text_inputs)

# %% [markdown]
# normalize features

# %%
image_features /= image_features.norm(dim=-1, keepdim=True)
text_features /= text_features.norm(dim=-1, keepdim=True)

# %% [markdown]
# compute cosine similarity between image and text embeddings

# %%
similarity = (100.0 * image_features @ text_features.T).softmax(dim=-1)

# %%
values, indices = similarity[0].topk(3)

for value, index in zip(values, indices):
    print(f"{cifar10_classes[index]:>16s}: {100 * value.item():.2f}%")
# Out:
#              dog: 69.04%
#              cat: 14.25%
#            horse: 3.89%

# %%
cifar10_classes[label]
# Out:
# 'dog'

# %% [markdown]
# full test set evaluation

# %%
testloader = torch.utils.data.DataLoader(testset, batch_size=32, shuffle=False)

correct = 0
total = 0

with torch.no_grad():
    for images, labels in tqdm(testloader, desc="Evaluating", unit="batch"):
        images = images.to(device)
        labels = labels.to(device)

        image_features = model.encode_image(images)
        image_features /= image_features.norm(dim=-1, keepdim=True)

        similarities = image_features @ text_features.T
        predictions = similarities.argmax(dim=1)

        correct += (predictions == labels).sum().item()
        total += labels.size(0)

accuracy = correct / total * 100
print(f"zero-shot classification accuracy on CIFAR-10: {accuracy:.2f}%")
# Out:
# Evaluating: 100%|██████████| 313/313 [00:47<00:00,  6.63batch/s]
# zero-shot classification accuracy on CIFAR-10: 84.72%
