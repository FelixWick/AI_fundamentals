# %%
! pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in /Users/wick/language_models/.venv/lib/python3.13/site-packages (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from tiktoken) (2025.10.23)
# Requirement already satisfied: requests>=2.26.0 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wick/language_models/.venv/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken) (2025.10.5)

# %%
import tiktoken

# %%
# Choose a tokenizer for a specific model
# (you can use "gpt-4", "gpt-4o-mini", "gpt-3.5-turbo", etc.)
encoding = tiktoken.encoding_for_model("gpt-4")

# %%
# Example text
text = "ChatGPT is great at explaining things clearly!"

# %%
# Encode (text → tokens)
tokens = encoding.encode(text)
print("Tokens:", tokens)
print("Number of tokens:", len(tokens))
# Out:
# Tokens: [16047, 38, 2898, 374, 2294, 520, 26073, 2574, 9539, 0]
# Number of tokens: 10

# %%
# Decode (tokens → text)
decoded_text = encoding.decode(tokens)
print("Decoded text:", decoded_text)
# Out:
# Decoded text: ChatGPT is great at explaining things clearly!
