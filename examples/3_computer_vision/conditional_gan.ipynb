# %% [markdown]
# see https://github.com/huggingface/pytorch-pretrained-BigGAN

# %%
! pip install pytorch-pretrained-biggan
! pip install nltk
# Out:
# Requirement already satisfied: pytorch-pretrained-biggan in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (0.1.1)
# Requirement already satisfied: torch>=0.4.1 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from pytorch-pretrained-biggan) (2.7.0)
# Requirement already satisfied: numpy in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from pytorch-pretrained-biggan) (2.2.5)
# Requirement already satisfied: boto3 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from pytorch-pretrained-biggan) (1.38.17)
# Requirement already satisfied: requests in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from pytorch-pretrained-biggan) (2.32.3)
# Requirement already satisfied: tqdm in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from pytorch-pretrained-biggan) (4.67.1)
# Requirement already satisfied: filelock in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torch>=0.4.1->pytorch-pretrained-biggan) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torch>=0.4.1->pytorch-pretrained-biggan) (4.13.2)
# Requirement already satisfied: setuptools in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torch>=0.4.1->pytorch-pretrained-biggan) (80.7.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torch>=0.4.1->pytorch-pretrained-biggan) (1.14.0)
# Requirement already satisfied: networkx in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torch>=0.4.1->pytorch-pretrained-biggan) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torch>=0.4.1->pytorch-pretrained-biggan) (3.1.6)
# Requirement already satisfied: fsspec in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torch>=0.4.1->pytorch-pretrained-biggan) (2025.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=0.4.1->pytorch-pretrained-biggan) (1.3.0)
# Requirement already satisfied: botocore<1.39.0,>=1.38.17 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from boto3->pytorch-pretrained-biggan) (1.38.17)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from boto3->pytorch-pretrained-biggan) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from boto3->pytorch-pretrained-biggan) (0.12.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from botocore<1.39.0,>=1.38.17->boto3->pytorch-pretrained-biggan) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from botocore<1.39.0,>=1.38.17->boto3->pytorch-pretrained-biggan) (2.4.0)
# Requirement already satisfied: six>=1.5 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.39.0,>=1.38.17->boto3->pytorch-pretrained-biggan) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from jinja2->torch>=0.4.1->pytorch-pretrained-biggan) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from requests->pytorch-pretrained-biggan) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from requests->pytorch-pretrained-biggan) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from requests->pytorch-pretrained-biggan) (2025.4.26)
# Requirement already satisfied: nltk in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (3.9.1)
# Requirement already satisfied: click in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from nltk) (8.2.0)
# Requirement already satisfied: joblib in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from nltk) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from nltk) (4.67.1)

# %%
import torch
import matplotlib.pyplot as plt
from pytorch_pretrained_biggan import (BigGAN, one_hot_from_names, truncated_noise_sample, convert_to_images)

# %% [markdown]
# BigGAN is a class-conditional GAN, meaning it generates images based on ImageNet class labels (1,000 categories like "dog," "cat," "airplane") rather than free-form text prompts.

# %% [markdown]
# load pre-trained model tokenizer (vocabulary)

# %%
model = BigGAN.from_pretrained('biggan-deep-256')

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/wick/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
if torch.cuda.is_available():
    dev = "cuda:0"
elif torch.backends.mps.is_available():
    dev = "mps"
else:
    dev = "cpu"
device = torch.device(dev)
device
# Out:
# device(type='mps')

# %% [markdown]
# Create a one-hot vector from the name of an imagenet class ('tennis ball', 'daisy', ...). We use NLTK's wordnet search to try to find the relevant synset of ImageNet and take the first one. If we can't find it direcly, we look at the hyponyms and hypernyms of the class name.

# %%
truncation = 0.4
class_vector = one_hot_from_names(['soap bubble', 'coffee', 'mushroom'], batch_size=3)
noise_vector = truncated_noise_sample(truncation=truncation, batch_size=3)

noise_vector = torch.from_numpy(noise_vector)
class_vector = torch.from_numpy(class_vector)

# %%
noise_vector = noise_vector.to(device)
class_vector = class_vector.to(device)
model.to(device)
# Out:
# BigGAN(
#   (embeddings): Linear(in_features=1000, out_features=128, bias=False)
#   (generator): Generator(
#     (gen_z): Linear(in_features=256, out_features=32768, bias=True)
#     (layers): ModuleList(
#       (0-2): 3 x GenBlock(
#         (bn_0): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=2048, bias=False)
#           (offset): Linear(in_features=256, out_features=2048, bias=False)
#         )
#         (conv_0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#         (bn_1): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=512, bias=False)
#           (offset): Linear(in_features=256, out_features=512, bias=False)
#         )
#         (conv_1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_2): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=512, bias=False)
#           (offset): Linear(in_features=256, out_features=512, bias=False)
#         )
#         (conv_2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_3): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=512, bias=False)
#           (offset): Linear(in_features=256, out_features=512, bias=False)
#         )
#         (conv_3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU()
#       )
#       (3): GenBlock(
#         (bn_0): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=2048, bias=False)
#           (offset): Linear(in_features=256, out_features=2048, bias=False)
#         )
#         (conv_0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#         (bn_1): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=512, bias=False)
#           (offset): Linear(in_features=256, out_features=512, bias=False)
#         )
#         (conv_1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_2): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=512, bias=False)
#           (offset): Linear(in_features=256, out_features=512, bias=False)
#         )
#         (conv_2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_3): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=512, bias=False)
#           (offset): Linear(in_features=256, out_features=512, bias=False)
#         )
#         (conv_3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU()
#       )
#       (4-6): 3 x GenBlock(
#         (bn_0): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=1024, bias=False)
#           (offset): Linear(in_features=256, out_features=1024, bias=False)
#         )
#         (conv_0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (bn_1): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=256, bias=False)
#           (offset): Linear(in_features=256, out_features=256, bias=False)
#         )
#         (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_2): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=256, bias=False)
#           (offset): Linear(in_features=256, out_features=256, bias=False)
#         )
#         (conv_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_3): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=256, bias=False)
#           (offset): Linear(in_features=256, out_features=256, bias=False)
#         )
#         (conv_3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU()
#       )
#       (7): GenBlock(
#         (bn_0): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=1024, bias=False)
#           (offset): Linear(in_features=256, out_features=1024, bias=False)
#         )
#         (conv_0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (bn_1): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=256, bias=False)
#           (offset): Linear(in_features=256, out_features=256, bias=False)
#         )
#         (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_2): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=256, bias=False)
#           (offset): Linear(in_features=256, out_features=256, bias=False)
#         )
#         (conv_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_3): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=256, bias=False)
#           (offset): Linear(in_features=256, out_features=256, bias=False)
#         )
#         (conv_3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU()
#       )
#       (8): SelfAttn(
#         (snconv1x1_theta): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (snconv1x1_phi): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (snconv1x1_g): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (snconv1x1_o_conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (softmax): Softmax(dim=-1)
#       )
#       (9): GenBlock(
#         (bn_0): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=512, bias=False)
#           (offset): Linear(in_features=256, out_features=512, bias=False)
#         )
#         (conv_0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn_1): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=128, bias=False)
#           (offset): Linear(in_features=256, out_features=128, bias=False)
#         )
#         (conv_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_2): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=128, bias=False)
#           (offset): Linear(in_features=256, out_features=128, bias=False)
#         )
#         (conv_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_3): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=128, bias=False)
#           (offset): Linear(in_features=256, out_features=128, bias=False)
#         )
#         (conv_3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU()
#       )
#       (10): GenBlock(
#         (bn_0): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=512, bias=False)
#           (offset): Linear(in_features=256, out_features=512, bias=False)
#         )
#         (conv_0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn_1): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=128, bias=False)
#           (offset): Linear(in_features=256, out_features=128, bias=False)
#         )
#         (conv_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_2): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=128, bias=False)
#           (offset): Linear(in_features=256, out_features=128, bias=False)
#         )
#         (conv_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_3): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=128, bias=False)
#           (offset): Linear(in_features=256, out_features=128, bias=False)
#         )
#         (conv_3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU()
#       )
#       (11): GenBlock(
#         (bn_0): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=256, bias=False)
#           (offset): Linear(in_features=256, out_features=256, bias=False)
#         )
#         (conv_0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn_1): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=64, bias=False)
#           (offset): Linear(in_features=256, out_features=64, bias=False)
#         )
#         (conv_1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_2): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=64, bias=False)
#           (offset): Linear(in_features=256, out_features=64, bias=False)
#         )
#         (conv_2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_3): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=64, bias=False)
#           (offset): Linear(in_features=256, out_features=64, bias=False)
#         )
#         (conv_3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU()
#       )
#       (12): GenBlock(
#         (bn_0): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=256, bias=False)
#           (offset): Linear(in_features=256, out_features=256, bias=False)
#         )
#         (conv_0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn_1): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=64, bias=False)
#           (offset): Linear(in_features=256, out_features=64, bias=False)
#         )
#         (conv_1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_2): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=64, bias=False)
#           (offset): Linear(in_features=256, out_features=64, bias=False)
#         )
#         (conv_2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn_3): BigGANBatchNorm(
#           (scale): Linear(in_features=256, out_features=64, bias=False)
#           (offset): Linear(in_features=256, out_features=64, bias=False)
#         )
#         (conv_3): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU()
#       )
#     )
#     (bn): BigGANBatchNorm()
#     (relu): ReLU()
#     (conv_to_rgb): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (tanh): Tanh()
#   )
# )

# %%
with torch.no_grad():
    output = model(noise_vector, class_vector, truncation)

output = output.to('cpu')

# %%
images = convert_to_images(output)

# %%
for image in images:
    plt.imshow(image)
    plt.show()
