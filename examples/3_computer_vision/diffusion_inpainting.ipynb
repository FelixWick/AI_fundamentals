# %%
! pip install torch torchvision diffusers transformers accelerate safetensors pillow
# Out:
# Requirement already satisfied: torch in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (2.7.0)
# Requirement already satisfied: torchvision in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (0.22.0)
# Requirement already satisfied: diffusers in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (0.35.2)
# Requirement already satisfied: transformers in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (4.52.4)
# Requirement already satisfied: accelerate in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (1.11.0)
# Requirement already satisfied: safetensors in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (0.5.3)
# Requirement already satisfied: pillow in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (11.2.1)
# Requirement already satisfied: filelock in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torch) (4.13.2)
# Requirement already satisfied: setuptools in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torch) (80.7.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: numpy in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from torchvision) (2.2.5)
# Requirement already satisfied: importlib_metadata in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from diffusers) (8.7.0)
# Requirement already satisfied: huggingface-hub>=0.34.0 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from diffusers) (0.36.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: packaging>=20.0 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from transformers) (0.21.1)
# Requirement already satisfied: tqdm>=4.27 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from huggingface-hub>=0.34.0->diffusers) (1.1.5)
# Requirement already satisfied: psutil in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from importlib_metadata->diffusers) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from requests->diffusers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from requests->diffusers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wick/computer_vision/.venv/lib/python3.13/site-packages (from requests->diffusers) (2025.4.26)

# %%
import torch
from diffusers import StableDiffusionInpaintPipeline
from PIL import Image, ImageDraw

# %%
# Choose a model from Hugging Face
model_id = "runwayml/stable-diffusion-v1-5"  # You can change this to another model

# %%
device = (
    torch.device("cuda") if torch.cuda.is_available()
    else torch.device("mps") if torch.backends.mps.is_available()
    else torch.device("cpu")
)
print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
# Load the pipeline
pipe = StableDiffusionInpaintPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to(device)
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
def make_circle_mask(width, height, radius=None):
    # Create a black image (keep area)
    mask = Image.new("L", (width, height), 0)
    draw = ImageDraw.Draw(mask)

    # Default radius = half width
    if radius is None:
        radius = min(width, height) // 3

    # Center of the image
    cx, cy = width // 2, height // 2

    # Draw white circle (inpaint area)
    draw.ellipse(
        (cx - radius, cy - radius, cx + radius, cy + radius),
        fill=255
    )

    # Convert to RGB because diffusers expects RGB
    return mask.convert("RGB")

# %%
width, height = 512, 512
mask_image = make_circle_mask(width, height, 100)
mask_image.save("mask.png")

# %%
# Load your input image
# base_image: the image you want to modify
# mask_image: white = inpaint area, black = keep area
base_image = Image.open("img2img_result.png").convert("RGB")
mask_image = Image.open("mask.png").convert("RGB")   # must be RGB for the pipeline

# %%
# Optional but recommended: ensure both are the same size and divisible by 8
W, H = base_image.size
new_W, new_H = W - W % 8, H - H % 8
base_image = base_image.resize((new_W, new_H))
mask_image = mask_image.resize((new_W, new_H))

# %%
# Text conditioning
prompt = "A fantasy dragon replacing the masked region, highly detailed"

# %%
# Run the inpainting pipeline
result = pipe(
    prompt=prompt,
    image=base_image,
    mask_image=mask_image,
    num_inference_steps=50,
    guidance_scale=7.5,
    strength=0.8,   # how much to transform the masked region
).images[0]
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
# Save the generated image
result.save("inpaint_result.png")
print("Saved inpaint_result.png")
# Out:
# Saved inpaint_result.png
